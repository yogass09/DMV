# %%
import mysql.connector
import pandas as pd

# Establishing the connection
con = mysql.connector.connect(
    host="dbcp.cry66wamma47.ap-south-1.rds.amazonaws.com",
    port=3306,
    user="yogass09",
    password="jaimaakamakhya",
    database="dbcp"
)

# Executing the query and fetching the results directly into a pandas DataFrame
query = "SELECT * FROM crypto_listings_latest"
crypto_listings_latest = pd.read_sql_query(query, con)

# Closing the connection
con.close()
# Out:
# C:\Users\Pranav Darekar\AppData\Local\Temp\ipykernel_19068\3109873822.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crypto_listings_latest = pd.read_sql_query(query, con)

# %%
# Sorting the DataFrame by the 'cmc_rank' column in ascending order
crypto_listings_latest_sorted = crypto_listings_latest.sort_values(by='cmc_rank')

# Filtering for the top 1000 cmc_rank
top_1000_cmc_rank = crypto_listings_latest_sorted.head(1000)

# %%
# Saving the filtered DataFrame to a CSV file
crypto_listings_latest_sorted.to_csv('crypto_listings_latest_sorted', index=False)
top_1000_cmc_rank.to_csv('top_1000_cmc_rank.csv', index=False)

# %%
con = mysql.connector.connect(
    host="dbcp.cry66wamma47.ap-south-1.rds.amazonaws.com",
    port=3306,
    user="yogass09",
    password="jaimaakamakhya",
    database="dbcp"
)

# %%
# Getting a list of all unique values under the 'slug' column
slug_list = top_1000_cmc_rank['slug'].unique().tolist()

# Constructing the SQL query to fetch data for the specific slugs
placeholders = ', '.join(['%s'] * len(slug_list))
query = f"SELECT * FROM all_coins_ohlcv WHERE slug IN ({placeholders})"

# Executing the query and fetching the results directly into a pandas DataFrame
all_coins_ohlcv_filtered = pd.read_sql_query(query, con, params=slug_list)

all_coins_ohlcv_filtered.to_csv('all_coins_ohlcv_filtered', index=False)

# Displaying the DataFrame (optional)
print("Filtered all_coins_ohlcv DataFrame:")
# Out:
# C:\Users\Pranav Darekar\AppData\Local\Temp\ipykernel_19068\528456090.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   all_coins_ohlcv_filtered = pd.read_sql_query(query, con, params=slug_list)
# Filtered all_coins_ohlcv DataFrame:

# %%
all_coins_ohlcv_filtered.head()
# Out:
#        id    slug    name  symbol            timestamp  ref_cur_id  \
# 0  9481.0  pendle  Pendle  PENDLE  2023-09-17 23:59:59      2781.0
# 1  9481.0  pendle  Pendle  PENDLE  2023-09-18 23:59:59      2781.0
# 2  9481.0  pendle  Pendle  PENDLE  2023-09-19 23:59:59      2781.0
# 3  9481.0  pendle  Pendle  PENDLE  2023-09-20 23:59:59      2781.0
# 4  9481.0  pendle  Pendle  PENDLE  2023-09-21 23:59:59      2781.0
#
#   ref_cur_name   time_open           time_close            time_high  \
# 0          USD  2023-09-17  2023-09-17 23:59:59  2023-09-17 00:00:00
# 1          USD  2023-09-18  2023-09-18 23:59:59  2023-09-18 15:49:00
# 2          USD  2023-09-19  2023-09-19 23:59:59  2023-09-19 15:37:00
# 3          USD  2023-09-20  2023-09-20 23:59:59  2023-09-20 23:50:00
# 4          USD  2023-09-21  2023-09-21 23:59:59  2023-09-21 00:59:00
#
#               time_low      open      high       low     close       volume  \
# ...
